# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
df=pd.read_csv("/content/drive/My Drive/Colab Notebooks/bismillah.csv").values
data=pd.DataFrame(df)
#data.columns=["v1","v2","v3","v4","v5","v6"]
#data=data.sort_values
print(data)
# Out:
#              0           1    2    3    4    5
# 0    -7.350160  112.671876  0.0  0.0  0.0  1.0
# 1    -7.350073  112.674911  0.0  0.0  0.0  2.0
# 2    -7.349885  112.676766  0.0  0.0  0.0  1.0
# 3    -7.349623  112.674038  1.0  0.0  1.0  0.0
# 4    -7.349467  112.678449  0.0  0.0  0.0  1.0
# ...        ...         ...  ...  ...  ...  ...
# 1320 -7.205265  112.650496  2.0  1.0  0.0  0.0
# 1321 -7.204141  112.635981  2.0  1.0  0.0  0.0
# 1322 -7.203778  112.649781  0.0  0.0  0.0  2.0
# 1323 -7.196221  112.645899  0.0  0.0  0.0  1.0
# 1324 -7.192814  112.640189  1.0  0.0  1.0  0.0
#
# [1325 rows x 6 columns]

# %%
#iki
#kmeans.fit(data)
#predict=kmeans.predict(data)
#data["cluster"]=predict
#data=data.sort_values("cluster")
#sns.scatterplot(data[0],data[1],hue=data["cluster"])
#plt.show

# %%
kmeans=KMeans(n_clusters=5,n_init=100)
kmeans.fit(data[[0,1]])
silhouette_avg=silhouette_score(data,kmeans.labels_)
print(silhouette_avg)
# Out:
# -0.08366354285687422

# %%
plt.scatter(data[[0]],data[[1]],c=kmeans.labels_,cmap='rainbow')
plt.xlabel("x")
plt.ylabel("y")
plt.title("tugas")
plt.show
predict=kmeans.predict(data[[0,1]])
data["cluster"]=predict
data=data.sort_values("cluster")

# %%
#iki
data.to_csv (r'/content/drive/My Drive/Colab Notebooks/hasil.csv')
